# %%
class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, year_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.year_of_experience = year_of_experience

    def __str__(self):
        return (f"Employee(Name: {self.name}, Number: {self.number}, Address: {self.address}, "
                f"Salary: {self.salary}, Post: {self.post}, Year of Joining: {self.year_of_joining}, "
                f"Education: {self.education}, Years of Experience: {self.year_of_experience})")

if __name__ == "__main__":
    emp = Employee(
        name="Muhammad Faraz",
        number="E123",
        address="gulshan-e-iqbal karachi",
        salary=50000,
        post="Software Engineer",
        year_of_joining=2015,
        education="Bachelor's in Computer Science",
        year_of_experience=9
    )
    
    print(emp)
# Out:
# Employee(Name: Muhammad Faraz, Number: E123, Address: gulshan-e-iqbal karachi, Salary: 50000, Post: Software Engineer, Year of Joining: 2015, Education: Bachelor's in Computer Science, Years of Experience: 9)

# %%
class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, year_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.year_of_experience = year_of_experience

    def describe_employee(self):
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: {self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.year_of_experience}")

    def update_year_of_experience(self, new_year_of_experience):
        self.year_of_experience = new_year_of_experience

    def increase_salary(self, amount):
        self.salary += amount

    def __str__(self):
        return (f"Employee(Name: {self.name}, Number: {self.number}, Address: {self.address}, "
                f"Salary: {self.salary}, Post: {self.post}, Year of Joining: {self.year_of_joining}, "
                f"Education: {self.education}, Years of Experience: {self.year_of_experience})")

if __name__ == "__main__":
    emp = Employee(
        name="Muhammad Faraz",
        number="E123",
        address="gulshan-e-iqbal karachi",
        salary=50000,
        post="Software Engineer",
        year_of_joining=2015,
        education="Bachelor's in Computer Science",
        year_of_experience=9
    )
    
    emp.describe_employee()
    emp.update_year_of_experience(10)
    emp.increase_salary(5000)
    print(emp)
# Out:
# Name: Muhammad Faraz
# Number: E123
# Address: gulshan-e-iqbal karachi
# Salary: 50000
# Post: Software Engineer
# Year of Joining: 2015
# Education: Bachelor's in Computer Science
# Years of Experience: 9
# Employee(Name: Muhammad Faraz, Number: E123, Address: gulshan-e-iqbal karachi, Salary: 55000, Post: Software Engineer, Year of Joining: 2015, Education: Bachelor's in Computer Science, Years of Experience: 10)

# %%
class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, year_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.year_of_experience = year_of_experience

    def describe_employee(self):
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: {self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.year_of_experience}")

    def update_year_of_experience(self, new_year_of_experience):
        self.year_of_experience = new_year_of_experience

    def increase_salary(self, amount):
        self.salary += amount

    def __str__(self):
        return (f"Employee(Name: {self.name}, Number: {self.number}, Address: {self.address}, "
                f"Salary: {self.salary}, Post: {self.post}, Year of Joining: {self.year_of_joining}, "
                f"Education: {self.education}, Years of Experience: {self.year_of_experience})")

if __name__ == "__main__":
    employee101 = Employee(
        name="shayan khan",
        number="E101",
        address="buferzone karachi",
        salary=60000,
        post="Project Manager",
        year_of_joining=2018,
        education="Master's in Management",
        year_of_experience=6
    )

    print(employee101.name)
    print(employee101.number)
    print(employee101.address)
    print(employee101.salary)

    employee101.describe_employee()
    employee101.increase_salary(7000)
    employee101.update_year_of_experience(7)
    employee101.describe_employee()
    print(employee101)
# Out:
# shayan khan
# E101
# buferzone karachi
# 60000
# Name: shayan khan
# Number: E101
# Address: buferzone karachi
# Salary: 60000
# Post: Project Manager
# Year of Joining: 2018
# Education: Master's in Management
# Years of Experience: 6
# Name: shayan khan
# Number: E101
# Address: buferzone karachi
# Salary: 67000
# Post: Project Manager
# Year of Joining: 2018
# Education: Master's in Management
# Years of Experience: 7
# Employee(Name: shayan khan, Number: E101, Address: buferzone karachi, Salary: 67000, Post: Project Manager, Year of Joining: 2018, Education: Master's in Management, Years of Experience: 7)

# %%
class Employee:
    def __init__(self, name, number, address, salary, post, year_of_joining, education, year_of_experience):
        self.name = name
        self.number = number
        self.address = address
        self.salary = salary
        self.post = post
        self.year_of_joining = year_of_joining
        self.education = education
        self.year_of_experience = year_of_experience

    def describe_employee(self):
        print(f"Name: {self.name}")
        print(f"Number: {self.number}")
        print(f"Address: {self.address}")
        print(f"Salary: {self.salary}")
        print(f"Post: {self.post}")
        print(f"Year of Joining: {self.year_of_joining}")
        print(f"Education: {self.education}")
        print(f"Years of Experience: {self.year_of_experience}")
        print()

    def update_year_of_experience(self, new_year_of_experience):
        self.year_of_experience = new_year_of_experience

    def increase_salary(self, amount):
        self.salary += amount

    def __str__(self):
        return (f"Employee(Name: {self.name}, Number: {self.number}, Address: {self.address}, "
                f"Salary: {self.salary}, Post: {self.post}, Year of Joining: {self.year_of_joining}, "
                f"Education: {self.education}, Years of Experience: {self.year_of_experience})")

if __name__ == "__main__":
    employees = [
        Employee("shayan khan", "E101", "bufferzone karachi", 60000, "Project Manager", 2018, "Master's in Management", 6),
        Employee("bilal", "E102", "guslhan karachi", 55000, "Software Engineer", 2017, "Bachelor's in Computer Science", 7),
        Employee("faraz", "E103", "FB area", 62000, "Data Scientist", 2019, "Master's in Data Science", 5),
        Employee("wajid", "E104", "pechs,karachi", 50000, "Marketing Specialist", 2020, "Bachelor's in Marketing", 4),
        Employee("haris", "E105", "FB area", 64000, "Product Manager", 2016, "Master's in Business Administration", 8),
        Employee("mani", "E106", "johar karachi", 57000, "UX Designer", 2019, "Bachelor's in Design", 5),
        Employee("wajji", "E107", "gulshan karachi", 59000, "HR Manager", 2018, "Master's in Human Resources", 6),
        Employee("ovais ahmed", "E108", "defence,karachi", 58000, "Sales Executive", 2021, "Bachelor's in Business Administration", 3),
        Employee("ali", "E109", "johar karachi", 61000, "Finance Analyst", 2017, "Master's in Finance", 7),
        Employee("arsam", "E110", "north karaxhi", 65000, "Operations Manager", 2015, "Bachelor's in Operations Management", 9)
    ]

    for employee in employees:
        employee.describe_employee()

    for employee in employees:
        employee.increase_salary(2000)
        employee.update_year_of_experience(employee.year_of_experience + 1)

    print("Updated employee details:")
    for employee in employees:
        employee.describe_employee()
# Out:
# Name: shayan khan
# Number: E101
# Address: bufferzone karachi
# Salary: 60000
# Post: Project Manager
# Year of Joining: 2018
# Education: Master's in Management
# Years of Experience: 6
#
# Name: bilal
# Number: E102
# Address: guslhan karachi
# Salary: 55000
# Post: Software Engineer
# Year of Joining: 2017
# Education: Bachelor's in Computer Science
# Years of Experience: 7
#
# Name: faraz
# Number: E103
# Address: FB area
# Salary: 62000
# Post: Data Scientist
# Year of Joining: 2019
# Education: Master's in Data Science
# Years of Experience: 5
#
# Name: wajid
# Number: E104
# Address: pechs,karachi
# Salary: 50000
# Post: Marketing Specialist
# Year of Joining: 2020
# Education: Bachelor's in Marketing
# Years of Experience: 4
#
# Name: haris
# Number: E105
# Address: FB area
# Salary: 64000
# Post: Product Manager
# Year of Joining: 2016
# Education: Master's in Business Administration
# Years of Experience: 8
#
# Name: mani
# Number: E106
# Address: johar karachi
# ...

# %%
employees = [
    {"name": "shayan khan", "number": "E101", "address": "bufferzone karachi", "salary": 60000, "post": "Project Manager", "year_of_joining": 2018, "education": "Master's in Management", "year_of_experience": 6},
    {"name": "bilal", "number": "E102", "address": "guslhan karachi", "salary": 55000, "post": "Software Engineer", "year_of_joining": 2017, "education": "Bachelor's in Computer Science", "year_of_experience": 7},
    {"name": "faraz", "number": "E103", "address": "FB area", "salary": 62000, "post": "Data Scientist", "year_of_joining": 2019, "education": "Master's in Data Science", "year_of_experience": 5},
    {"name": "wajid", "number": "E104", "address": "pechs,karachi", "salary": 50000, "post": "Marketing Specialist", "year_of_joining": 2020, "education": "Bachelor's in Marketing", "year_of_experience": 4},
    {"name": "haris", "number": "E105", "address": "FB area", "salary": 64000, "post": "Product Manager", "year_of_joining": 2016, "education": "Master's in Business Administration", "year_of_experience": 8},
    {"name": "mani", "number": "E106", "address": "johar karachi", "salary": 57000, "post": "UX Designer", "year_of_joining": 2019, "education": "Bachelor's in Design", "year_of_experience": 5},
    {"name": "wajji", "number": "E107", "address": "gulshan karachi", "salary": 59000, "post": "HR Manager", "year_of_joining": 2018, "education": "Master's in Human Resources", "year_of_experience": 6},
    {"name": "ovais ahmed", "number": "E108", "address": "defence,karachi", "salary": 58000, "post": "Sales Executive", "year_of_joining": 2021, "education": "Bachelor's in Business Administration", "year_of_experience": 3},
    {"name": "ali", "number": "E109", "address": "johar karachi", "salary": 61000, "post": "Finance Analyst", "year_of_joining": 2017, "education": "Master's in Finance", "year_of_experience": 7},
    {"name": "arsam", "number": "E110", "address": "north karachi", "salary": 65000, "post": "Operations Manager", "year_of_joining": 2015, "education": "Bachelor's in Operations Management", "year_of_experience": 9}
]

def describe_employee(employee):
    print(f"Name: {employee['name']}")
    print(f"Number: {employee['number']}")
    print(f"Address: {employee['address']}")
    print(f"Salary: {employee['salary']}")
    print(f"Post: {employee['post']}")
    print(f"Year of Joining: {employee['year_of_joining']}")
    print(f"Education: {employee['education']}")
    print(f"Years of Experience: {employee['year_of_experience']}")
    print()

for employee in employees:
    describe_employee(employee)

for employee in employees:
    employee['salary'] += 2000
    employee['year_of_experience'] += 1

print("Updated employee details:")
for employee in employees:
    describe_employee(employee)
# Out:
# Name: shayan khan
# Number: E101
# Address: bufferzone karachi
# Salary: 60000
# Post: Project Manager
# Year of Joining: 2018
# Education: Master's in Management
# Years of Experience: 6
#
# Name: bilal
# Number: E102
# Address: guslhan karachi
# Salary: 55000
# Post: Software Engineer
# Year of Joining: 2017
# Education: Bachelor's in Computer Science
# Years of Experience: 7
#
# Name: faraz
# Number: E103
# Address: FB area
# Salary: 62000
# Post: Data Scientist
# Year of Joining: 2019
# Education: Master's in Data Science
# Years of Experience: 5
#
# Name: wajid
# Number: E104
# Address: pechs,karachi
# Salary: 50000
# Post: Marketing Specialist
# Year of Joining: 2020
# Education: Bachelor's in Marketing
# Years of Experience: 4
#
# Name: haris
# Number: E105
# Address: FB area
# Salary: 64000
# Post: Product Manager
# Year of Joining: 2016
# Education: Master's in Business Administration
# Years of Experience: 8
#
# Name: mani
# Number: E106
# Address: johar karachi
# ...
